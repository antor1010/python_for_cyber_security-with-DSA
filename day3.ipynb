# %% [markdown]
# <a href="https://colab.research.google.com/github/antor1010/python_for_cyber_security-with-OOP_and_DSA/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#formatted
num1=10
num2=20
print(f"{num1}+{num2}={num1+num2}")
#end=""
name="Antor."
dept="CSE"
print(name,end=" ")
print(dept)
# Out:
# 10+20=30
# Antor. CSE

# %%
#string
name="I'm \"Antor Biswas\""
x="\nCSE\"CyberSecurity\""
print(name+x)     # + or ,
x="I am antor"
print(x[6:])
print(type(x))
# Out:
# I'm "Antor Biswas"
# CSE"CyberSecurity"
# ntor
# <class 'str'>

# %%
#replace
a='''I'm \"Antor Biswas\"
CSE(Cybersecurity)'''
print(a)
#replace
b=a.replace("Antor Biswas","Antor B")
print(b)
demo='''Hi this is Antor From BD.
Hi this is Antor From BD.
Hi this is Antor From BD.
'''
print(demo,"After replace")
re=demo.replace("BD","Bangladesh",1)
print(re)
# Out:
# I'm "Antor Biswas"
# CSE(Cybersecurity)
# I'm "Antor B"
# CSE(Cybersecurity)
# Hi this is Antor From BD.
# Hi this is Antor From BD.
# Hi this is Antor From BD.
#  After replace
# Hi this is Antor From Bangladesh.
# Hi this is Antor From BD.
# Hi this is Antor From BD.

# %%
#replace
x="Antar"
x=x[:3]+'o'+x[4:]
print(x)
# Out:
# Antor

# %%
#Upper and Lower
x="I am Antor Biswas"
print(x.upper())
print(x.lower())
# Out:
# I AM ANTOR BISWAS
# i am antor biswas

# %%
#string remove
x="Antor Biswas"
r=x.strip("As") #remove 1st and last
print(r)
# Out:
# ntor Biswa

# %%
#join
x="Antor"
b="CSE"
print("$b1".join(x)) #for better passwd
print(" ".join([x,b]))

t=("Antor","Biswas","CSE","CyberSecurity")
print(" $ ".join(t))
l=["Antor","Biswas","CSE","CyberSecurity"]
print(" % ".join(l))
s={"Antor","Biswas","CSE","CyberSecurity"}
print(" & ".join(s))

name="Antor"
print("".join([name," Biswas"]))
# Out:
# A$b1n$b1t$b1o$b1r
# Antor CSE
# Antor $ Biswas $ CSE $ CyberSecurity
# Antor % Biswas % CSE % CyberSecurity
# Biswas & Antor & CyberSecurity & CSE
# Antor Biswas

# %%
#insert
hack="Welcome to %s and %s course"
c="Cyber Security"
p="Python"
print(hack%(c,p))
x="Error %d"
i=404
print(x%i)
# Out:
# Welcome to Cyber Security and Python course
# Error 404

# %%
#insert
hack="Welcome to {} and {} course"
c="Cyber Security"
p="Python"
print(hack.format(c,p))
# Out:
# Welcome to Cyber Security and Python course

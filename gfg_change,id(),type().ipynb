# %%
print("Hello")
# Out:
# Hello

# %%
#basic
print("GFG")
"""use multi comment
here"""
print("Antor")
# Out:
# GFG
# Antor

# %%
#wrong 
x=100
y=20
x=y
y=x
print(x)
print(y)
# Out:
# 20
# 20

# %%
#change
x=100
y=20
temp=x
x=y
y=temp
print(x,y)
# Out:
# 20 100

# %%
#id()
x=10
y=x
print(id(x))
print(id(y))
# Out:
# 3872396
# 3872396

# %%
x=[1,2]
y=[1,2]
print(id(x))
print(id(y))
# Out:
# 70430176
# 63969552

# %%
print(x is y)
print(x == y)
# Out:
# False
# True

# %%
print(x,y)
# Out:
# [1, 2] [1, 2]

# %%
#type()
x="Antor"
y=10
print(type(x) is type(y))
# Out:
# False

# %%
A=type("B",(),{"x":10})
b=A()
print(type(b))
print(b.x)
# Out:
# <class '__main__.B'>
# 10

# %%
A=type("A",(),{"n":"Antor", "show": lambda self: self.n})
obj=A()
print(obj.n)
print(type(obj))
print(obj.show())
# Out:
# Antor
# <class '__main__.A'>
# Antor

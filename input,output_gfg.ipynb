# %%
#input
name=input("What is your name?")
print("your name is ",name)
print(len(name))
print(name.index("A"))
# Out:
# What is your name? Antor
# your name is  Antor
# 5
# 0

# %%
a=input()
b=input()
separator = input()[0]
print(a, b)
print(a, b,end=" ")
print(a, b, sep=separator)
print(a, b, sep='')

c=input()
n=int(input())
print(c*n)
# Out:
#  xz
#  f
#  gu
# xz f
# xz f xzgf
# xzf
#  ss
#  5
# ssssssssss

# %%
#scientific method
a = float(input())
print(f"{a:.4e}")
# Out:
#  5.24
# 5.2400e+00

# %%
a=float(input())
b=float(input())
print(f"{a/b:.3f}")
# Out:
#  10.0
#  3.0
# 3.333

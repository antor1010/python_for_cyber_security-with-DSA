# %% [markdown]
# <a href="https://colab.research.google.com/github/antor1010/python_for_cyber_security-with-DSA/blob/main/python_Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#python Variable and Data types

first_name="Antor"
last_name="Biswas"
dept="CSE(CyberSecurity)"

print("This is "+first_name ,last_name)
print("CSE(cyberSecurity)")
print(type(first_name))
# Out:
# This is Antor Biswas
# CSE(cyberSecurity)
# <class 'str'>

# %%
x = 2.0      # global variable

def myfunc():
    x = 'Antor Biswas'   # local variable
    print("my name is", x)  #inside function so output must be local variable
    print(type(x))

myfunc()
print("My name is", x)    #global variable
print(type(x))
# Out:
# my name is Antor Biswas
# <class 'str'>
# My name is 2.0
# <class 'float'>

# %%
#global Varible only
x=50
def mySecfunc():
  print("Output is",x)
mySecfunc()
print(type(x))
# Out:
# Output is 50
# <class 'int'>

# %%
#data type
x=5
y=10.10
name="Antor"
xy=['Antor','Biswas','CSE(cyberSecurity)']
yz={'Antor','Biswas','CSE(cyberSecurity)'}
xz=('Antor','Biswas','CSE(cyberSecurity)')
t=bool(5)
c=1j
print(type(x),type(y),type(name),type(xy),type(yz),type(xz),type(t),type(c))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'list'> <class 'set'> <class 'tuple'> <class 'bool'> <class 'complex'>

# %% [markdown]
# <a href="https://colab.research.google.com/github/antor1010/python_for_cyber_security-with-DSA/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#index number
x="Antor Biswas"
print(x)
print(x[0])
print(x[:5])
print(x[-1])
print(x[-6:])
# Out:
# Antor Biswas
# A
# Antor
# s
# Biswas

# %%
#index number use list
x=["Antor","Biswas","CSE(CyberSecurity)"]
print(x)
print(x[0])
print(x[0][0])
print(x[0][:5])
print(x[-1])
print(x[-1][-18:])
print(x[-1][-5])
print(x[1])
print(x[-2])
# Out:
# ['Antor', 'Biswas', 'CSE(CyberSecurity)']
# Antor
# A
# Antor
# CSE(CyberSecurity)
# CSE(CyberSecurity)
# r
# Biswas
# Biswas
